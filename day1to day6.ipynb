# %%
firstname='Negro'

# %%
Lastname='Shaikh'

# %%
fullname= f"{firstname} {Lastname}"

# %%
print(fullname)
# Out:
# Negro Shaikh

# %%
print(fullname.title())
# Out:
# Negro Shaikh

# %%
print(fullname.lower())
# Out:
# negro shaikh

# %%
laptop=' Dell'

# %%
print(laptop)
# Out:
#  Dell

# %%
print(laptop.lstrip())
# Out:
# Dell

# %%
message=f"This is good machine,{laptop.title()}"
print(message)
# Out:
# This is good machine, Dell

# %%
print("my_family:NabaZainabHasanHasnainOsmanMohammed")
# Out:
# my_family:NabaZainabHasanHasnainOsmanMohammed

# %%
print("my_family:nNabanZainabnHasannHasnainnOsmannMohammed")
# Out:
# my_family:nNabanZainabnHasannHasnainnOsmannMohammed

# %%
print("my_family:'Naba','Zainab','Hasan','Hasnain','Osman','Mohammed'")
# Out:
# my_family:'Naba','Zainab','Hasan','Hasnain','Osman','Mohammed'

# %%
print("my_family:'Naba',\n\,'Zainab',\n\'Hasan',\n\'Hasnain',\n\'Osman',\n\'Mohammed'")
# Out:
# my_family:'Naba',
# \,'Zainab',
# 'Hasan',
# 'Hasnain',
# 'Osman',
# 'Mohammed'

# %%
print("my_family:\n'Naba',\n,'Zainab',\n'Hasan',\n'Hasnain',\n'Osman',\n'Mohammed'")
# Out:
# my_family:
# 'Naba',
# ,'Zainab',
# 'Hasan',
# 'Hasnain',
# 'Osman',
# 'Mohammed'

# %%
Countries=['India','Malayasia','Indo','Pak','Afghan','Iran']

# %%
print(Countries)
# Out:
# ['India', 'Malayasia', 'Indo', 'Pak', 'Afghan', 'Iran']

# %%
print(Countries[2])
# Out:
# Indo

# %%
print(Countries[3].title())
# Out:
# Pak

# %%
Countries.append('USA')
print(Countries)
# Out:
# ['India', 'Malayasia', 'Indo', 'Pak', 'Afghan', 'Iran', 'USA', 'USA']

# %%
Countries.insert(2,'Japan')
print(Countries)
# Out:
# ['India', 'Malayasia', 'Japan', 'Japan', 'Indo', 'Pak', 'Afghan', 'Iran', 'USA', 'USA']

# %%
Countries[2]=('Vietnam')

# %%
Countries[8]=('Canada')

# %%
print(Countries)
# Out:
# ['India', 'Malayasia', 'Vietnam', 'Japan', 'Indo', 'Pak', 'Afghan', 'Iran', 'Canada', 'USA']

# %%
del Countries[5]
print(Countries)
# Out:
# ['India', 'Malayasia', 'Vietnam', 'Japan', 'Indo', 'Afghan', 'Iran', 'Canada', 'USA']

# %%
x=Countries.pop()
print(Countries)
# Out:
# ['India', 'Malayasia', 'Vietnam', 'Japan', 'Indo', 'Afghan', 'Iran', 'Canada']

# %%
print(Countries[0:5])
# Out:
# ['India', 'Malayasia', 'Vietnam', 'Japan', 'Indo']

# %%
print(Countries[2:7])
# Out:
# ['Vietnam', 'Japan', 'Indo', 'Afghan', 'Iran']

# %%
Countries.append('Palestine')
print(Countries)
# Out:
# ['India', 'Malayasia', 'Vietnam', 'Japan', 'Indo', 'Afghan', 'Iran', 'Canada', 'Palestine']

# %%
Countries.insert(2,'Egypt')
print(Countries)
# Out:
# ['India', 'Malayasia', 'Egypt', 'Vietnam', 'Japan', 'Indo', 'Afghan', 'Iran', 'Canada', 'Palestine']

# %%
print("Countries:\n\India\n\Malayasia\n\Egypt\n\Vietnam\n\Japan\n\Indo\n\Afghan\n\Iran\n\Canada\n\Palestine"
)
# Out:
# Countries:
# \India
# \Malayasia
# \Egypt
# \Vietnam
# \Japan
# \Indo
# \Afghan
# \Iran
# \Canada
# \Palestine

# %%
print("Countries:n India n Malayasia n Egypt n Vietnam n Japan n Indo n Afghan n Iran n Canada n Palestine"
)
# Out:
# Countries:n India n Malayasia n Egypt n Vietnam n Japan n Indo n Afghan n Iran n Canada n Palestine

# %%
print("Countries:\n India \n Malayasia \n Egypt \n Vietnam \n Japan \n Indo \n Afghan \n Iran \n Canada \n Palestine")
# Out:
# Countries:
#  India
#  Malayasia
#  Egypt
#  Vietnam
#  Japan
#  Indo
#  Afghan
#  Iran
#  Canada
#  Palestine

# %%
print(Countries.append('IsraHell'))
# Out:
# None

# %%
print(Countries)
# Out:
# ['India', 'Malayasia', 'Egypt', 'Vietnam', 'Japan', 'Indo', 'Afghan', 'Iran', 'Canada', 'Palestine', 'IsraHell']

# %%
Countries.insert(10,'Syria')
print(Countries)
# Out:
# ['India', 'Malayasia', 'Egypt', 'Vietnam', 'Japan', 'Indo', 'Afghan', 'Iran', 'Canada', 'Palestine', 'Syria', 'IsraHell']

# %%
print(Countries[1:11])
# Out:
# ['Malayasia', 'Egypt', 'Vietnam', 'Japan', 'Indo', 'Afghan', 'Iran', 'Canada', 'Palestine', 'Syria']

# %%
del Countries[0]

# %%
print(Countries)
# Out:
# ['Malayasia', 'Egypt', 'Vietnam', 'Japan', 'Indo', 'Afghan', 'Iran', 'Canada', 'Palestine', 'Syria', 'IsraHell']

# %%
x=Countries.pop()

# %%
print(Countries)
# Out:
# ['Malayasia', 'Egypt', 'Vietnam', 'Japan', 'Indo', 'Afghan', 'Iran', 'Canada', 'Palestine', 'Syria']

# %%
print(sorted(Countries))
# Out:
# ['Afghan', 'Canada', 'Egypt', 'Indo', 'Iran', 'Japan', 'Malayasia', 'Palestine', 'Syria', 'Vietnam']

# %%
Countries.sort()
print(Countries)
# Out:
# ['Afghan', 'Canada', 'Egypt', 'Indo', 'Iran', 'Japan', 'Malayasia', 'Palestine', 'Syria', 'Vietnam']

# %%
Countries.reverse()
print(Countries)
# Out:
# ['Vietnam', 'Syria', 'Palestine', 'Malayasia', 'Japan', 'Iran', 'Indo', 'Egypt', 'Canada', 'Afghan']

# %%
print(sorted(Countries))
# Out:
# ['Afghan', 'Canada', 'Egypt', 'Indo', 'Iran', 'Japan', 'Malayasia', 'Palestine', 'Syria', 'Vietnam']

# %%
Countries.sort()
print(Countries)
# Out:
# ['Afghan', 'Canada', 'Egypt', 'Indo', 'Iran', 'Japan', 'Malayasia', 'Palestine', 'Syria', 'Vietnam']

# %%
for a in Countries:
    print(a)
# Out:
# Afghan
# Canada
# Egypt
# Indo
# Iran
# Japan
# Malayasia
# Palestine
# Syria
# Vietnam

# %%
for a in Countries:
    print(f" all countrries are good,{a.title()}")
    print(f" but we love,{a.title()}")
# Out:
#  all countrries are good,Afghan
#  but we love,Afghan
#  all countrries are good,Canada
#  but we love,Canada
#  all countrries are good,Egypt
#  but we love,Egypt
#  all countrries are good,Indo
#  but we love,Indo
#  all countrries are good,Iran
#  but we love,Iran
#  all countrries are good,Japan
#  but we love,Japan
#  all countrries are good,Malayasia
#  but we love,Malayasia
#  all countrries are good,Palestine
#  but we love,Palestine
#  all countrries are good,Syria
#  but we love,Syria
#  all countrries are good,Vietnam
#  but we love,Vietnam

# %%
for a in Countries:
    print(f"best is the best,{a.title()}\n")
    print(f"but I love my countries,{a.title()}\n")
# Out:
# best is the best,Afghan
#
# but I love my countries,Afghan
#
# best is the best,Canada
#
# but I love my countries,Canada
#
# best is the best,Egypt
#
# but I love my countries,Egypt
#
# best is the best,Indo
#
# but I love my countries,Indo
#
# best is the best,Iran
#
# but I love my countries,Iran
#
# best is the best,Japan
#
# but I love my countries,Japan
#
# best is the best,Malayasia
#
# but I love my countries,Malayasia
#
# best is the best,Palestine
#
# but I love my countries,Palestine
#
# best is the best,Syria
#
# but I love my countries,Syria
#
# best is the best,Vietnam
#
# but I love my countries,Vietnam
