# %%
                "slicing the list

# %%
students =['abdullah','ramzan','Faiz','Mohan','Soha','Ritu','Kat']

# %% [raw]
# print(students)

# %%
print(students)
# Out:
# ['abdullah', 'ramzan', 'Faiz', 'Mohan', 'Soha', 'Ritu', 'Kat']

# %%
}print(students[0:1])
# Out:
# ['abdullah']

# %% [raw]
# rint(students[2:4])

# %%
print(students[2:4])
# Out:
# ['Faiz', 'Mohan']

# %%
print(students[3:8])
# Out:
# ['Mohan', 'Soha', 'Ritu', 'Kat']

# %%
print(students)
# Out:
# ['abdullah', 'ramzan', 'Faiz', 'Mohan', 'Soha', 'Ritu', 'Kat']

# %%
message = f"keep up good work, {students[0].title()}"

# %%
print(message)
# Out:
# keep up good work, Abdullah

# %%
message = f"keep up the goood work, {students[3].title()}"

# %%
print(message)
# Out:
# keep up the goood work, Mohan

# %%
for x in students:
    print (x)
# Out:
# abdullah
# ramzan
# Faiz
# Mohan
# Soha
# Ritu
# Kat

# %%
for x in students:
    print(f"keep up the good work,{x.title()}")
# Out:
# keep up the good work,Abdullah
# keep up the good work,Ramzan
# keep up the good work,Faiz
# keep up the good work,Mohan
# keep up the good work,Soha
# keep up the good work,Ritu
# keep up the good work,Kat

# %%
for a in students:
    print(f"keep up the good work,{a.title()}")
# Out:
# keep up the good work,Abdullah
# keep up the good work,Ramzan
# keep up the good work,Faiz
# keep up the good work,Mohan
# keep up the good work,Soha
# keep up the good work,Ritu
# keep up the good work,Kat

# %%
for a in students:
    print(f"keep up the good work,{a.title()}")
    print(f"do sumbit the work for today,{a.title()}")
# Out:
# keep up the good work,Abdullah
# do sumbit the work for today,Abdullah
# keep up the good work,Ramzan
# do sumbit the work for today,Ramzan
# keep up the good work,Faiz
# do sumbit the work for today,Faiz
# keep up the good work,Mohan
# do sumbit the work for today,Mohan
# keep up the good work,Soha
# do sumbit the work for today,Soha
# keep up the good work,Ritu
# do sumbit the work for today,Ritu
# keep up the good work,Kat
# do sumbit the work for today,Kat

# %%
for a in students:
    print(f"keep up the good work,{a.title()}")
    print(f"do sumbit the work for today,{a.title()}\n")
# Out:
# keep up the good work,Abdullah
# do sumbit the work for today,Abdullah
#
# keep up the good work,Ramzan
# do sumbit the work for today,Ramzan
#
# keep up the good work,Faiz
# do sumbit the work for today,Faiz
#
# keep up the good work,Mohan
# do sumbit the work for today,Mohan
#
# keep up the good work,Soha
# do sumbit the work for today,Soha
#
# keep up the good work,Ritu
# do sumbit the work for today,Ritu
#
# keep up the good work,Kat
# do sumbit the work for today,Kat
