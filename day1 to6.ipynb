# %%
firstname='Abdullah'
print(firstname)
# Out:
# Abdullah

# %%
lastname='Shaikh'
print(lastname)
# Out:
# Shaikh

# %%
print(firstname.lower())
# Out:
# abdullah

# %%
print(lastname.upper())
# Out:
# SHAIKH

# %%
fullname=f"{firstname} {lastname}"
print(fullname)
# Out:
# Abdullah Shaikh

# %%
message=f"keep up the good work,{fullname.title()}"

# %%
print(message)
# Out:
# keep up the good work,Abdullah Shaikh

# %%
print("fav_progr:python,c++,java,swift,cobalt")
# Out:
# fav_progr:python,c++,java,swift,cobalt

# %%
print("fav_progr:\n\python\n\c\n\c++\java\nswift\n\cobol")
# Out:
# fav_progr:
# \python
# \c
# \c++\java
# swift
# \cobol

# %%
print("fav_prog:\npython\nc\nswift\njava\ncobol")
# Out:
# fav_prog:
# python
# c
# swift
# java
# cobol

# %%
lang=" Python"
print(lang)
# Out:
#  Python

# %%
print(lang.lstrip())
# Out:
# Python

# %%
print(lang.rstrip())
# Out:
#  Python

# %%
students=['abdullah','shaikh','khan','sayyed','pathan']
print(students)
# Out:
# ['abdullah', 'shaikh', 'khan', 'sayyed', 'pathan']

# %%
print(students[0])
# Out:
# abdullah

# %%
print(students[2].title())
# Out:
# Khan

# %%
students.append('momin')

# %%
print(students)
# Out:
# ['abdullah', 'shaikh', 'khan', 'sayyed', 'pathan', 'momin']

# %%
students.insert(0,'alam')
print(students)
# Out:
# ['alam', 'alam', 'abdullah', 'shaikh', 'khan', 'sayyed', 'pathan', 'momin']

# %%
students[0]='Hasnain'
print(students)
# Out:
# ['Hasnain', 'alam', 'abdullah', 'shaikh', 'khan', 'sayyed', 'pathan', 'momin']

# %%
del students[6]
print(students)
# Out:
# ['Hasnain', 'alam', 'abdullah', 'shaikh', 'khan', 'sayyed', 'momin']

# %%
x=students.pop()
print(students)
# Out:
# ['Hasnain', 'alam', 'abdullah', 'shaikh', 'khan', 'sayyed']

# %%
print(sorted(students))
# Out:
# ['Hasnain', 'abdullah', 'alam', 'khan', 'sayyed', 'shaikh']

# %%
students.sort()
print(students)
# Out:
# ['Hasnain', 'abdullah', 'alam', 'khan', 'sayyed', 'shaikh']

# %%
students.reverse()
print(students)
# Out:
# ['shaikh', 'sayyed', 'khan', 'alam', 'abdullah', 'Hasnain']

# %%
students[3]='Osman'
print(students)
# Out:
# ['shaikh', 'sayyed', 'khan', 'Osman', 'abdullah', 'Hasnain']

# %%
print(students[2:5])
# Out:
# ['khan', 'Osman', 'abdullah']

# %%
message=f"keep up the good work,{students[0].title()}"

# %%
print(message)
# Out:
# keep up the good work,Shaikh

# %%
for x in students:
    print(x)
# Out:
# shaikh
# sayyed
# khan
# Osman
# abdullah
# Hasnain

# %%
for a in students:
    print(f"keep up the good work,{a.title()}")
# Out:
# keep up the good work,Shaikh
# keep up the good work,Sayyed
# keep up the good work,Khan
# keep up the good work,Osman
# keep up the good work,Abdullah
# keep up the good work,Hasnain

# %%
for a in students:
    print(a)
# Out:
# shaikh
# sayyed
# khan
# Osman
# abdullah
# Hasnain

# %%
for a in students:
    print(f"keep up the good work,{a.title()}")
    print(f"practice a lot,{a.title()}")
# Out:
# keep up the good work,Shaikh
# practice a lot,Shaikh
# keep up the good work,Sayyed
# practice a lot,Sayyed
# keep up the good work,Khan
# practice a lot,Khan
# keep up the good work,Osman
# practice a lot,Osman
# keep up the good work,Abdullah
# practice a lot,Abdullah
# keep up the good work,Hasnain
# practice a lot,Hasnain

# %%
for a in students:
    print(f"keep doing great things,{a.title()}")
    print(f"also believe in Allah,{a.title()}\n")
# Out:
# keep doing great things,Shaikh
# also believe in Allah,Shaikh
#
# keep doing great things,Sayyed
# also believe in Allah,Sayyed
#
# keep doing great things,Khan
# also believe in Allah,Khan
#
# keep doing great things,Osman
# also believe in Allah,Osman
#
# keep doing great things,Abdullah
# also believe in Allah,Abdullah
#
# keep doing great things,Hasnain
# also believe in Allah,Hasnain

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
type(students)
# Out:
# list
