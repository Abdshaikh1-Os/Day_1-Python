# %%
firstname=('Abdullah')
print(firstname)
# Out:
# Abdullah

# %% [raw]
# print(firstname.title())

# %%
print(firstname.lower())
# Out:
# abdullah

# %%
print(firstname.upper())
# Out:
# ABDULLAH

# %%
message=f"keep up the good work.{firstname.title()}"

# %%
print(message)
# Out:
# keep up the good work.Abdullah

# %%
lastname='Shaikh'
print(lastname)
# Out:
# Shaikh

# %%
firstname="Hasnain"

# %%
lastname="Shaikh"

# %%
fullname=f"{firstname} {lastname}"

# %%
print(fullname)
# Out:
# Hasnain Shaikh

# %%
fullname= firstname+" "+lastname
print(fullname)
# Out:
# Hasnain Shaikh

# %%
print(f" fav_cars:BMW,Audi,Lemosine")
# Out:
#  fav_cars:BMW,Audi,Lemosine

# %% [raw]
# print(f" fav_cars:\n\BMW\n\Audi\n\Lemo")

# %%
fav_cars=['BMW','Audi','Lemosine']
print(fav_cars)
# Out:
# ['BMW', 'Audi', 'Lemosine']

# %%
print(f" fav_cars:\n\Mercedes\n\Creta\n\Seltos")
# Out:
#  fav_cars:
# \Mercedes
# \Creta
# \Seltos

# %%
name=" Load"
print(name)
# Out:
#  Load

# %%
print(name.lstrip())
# Out:
# Load

# %%
name='sank '
print(name)
# Out:
# sank

# %%
print(name.rstrip())
# Out:
# sank

# %%
understanding the concept of indexing

# %%
students=['abd','boss','ron','don','ian']
print(students)
# Out:
# ['abd', 'boss', 'ron', 'don', 'ian']

# %%
print(students[0])
# Out:
# abd

# %%
print(students[3].title())
# Out:
# Don

# %%
students.append('Shane')
print(students)
# Out:
# ['abd', 'boss', 'ron', 'don', 'ian', 'Shane', 'Shane']

# %%
students.insert(2,'Osa')
print(students)
# Out:
# ['abd', 'boss', 'Osa', 'ron', 'don', 'ian', 'Shane', 'Shane']

# %%
students[6]='Has'

# %%
print(students)
# Out:
# ['abd', 'boss', 'Osa', 'ron', 'don', 'ian', 'Has', 'Shane']

# %%
del students[4]

# %%
print(students)
# Out:
# ['abd', 'boss', 'Osa', 'ron', 'ian', 'Has', 'Shane']

# %%
x=students.pop(1)
print(students)
# Out:
# ['abd', 'Osa', 'ron', 'ian', 'Has', 'Shane']

# %%
print(students)
# Out:
# ['abd', 'Osa', 'ron', 'ian', 'Has', 'Shane']

# %%
print(sorted.(students))
# Out:
#   Input In [63]
#     print(sorted.(students))
#                  ^
# SyntaxError: invalid syntax

# %%
students.sort()

# %%
print(students)
# Out:
# ['Has', 'Osa', 'Shane', 'abd', 'ian', 'ron']

# %%
students.reverse()

# %%
print(students)
# Out:
# ['ron', 'ian', 'abd', 'Shane', 'Osa', 'Has']

# %%
print(students[2:5])
# Out:
# ['abd', 'Shane', 'Osa']

# %%
print(students[1:7])
# Out:
# ['ian', 'abd', 'Shane', 'Osa', 'Has']
